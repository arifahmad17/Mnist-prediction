# %% [markdown]
# <a href="https://colab.research.google.com/github/arifahmad17/Mnist-prediction/blob/main/MNIST_data_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
mnist= tf.keras.datasets.mnist #28-28 images from 0-9

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
#normalise the inputs
x_train.shape
x_train=tf.keras.utils.normalize(x_train,axis=1)
x_test=tf.keras.utils.normalize(x_test,axis=1)
model=tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])
model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2632 - accuracy: 0.9232
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1084 - accuracy: 0.9663
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0739 - accuracy: 0.9762
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0550 - accuracy: 0.9822
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0411 - accuracy: 0.9866
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0312 - accuracy: 0.9898
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0263 - accuracy: 0.9910
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0207 - accuracy: 0.9930
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0175 - accuracy: 0.9939
# Epoch 10/10
# ...

# %%
#validation loss and accuracy

val_loss,val_acc=model.evaluate(x_test,y_test)
print(val_loss)
print("Accuracy = "+str(val_acc*100))
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1122 - accuracy: 0.9724
# 0.1122472807765007
# Accuracy = 97.24000096321106

# %%
#save your model
model.save("epic_num_reader.model")
#load the model
new_model=tf.keras.models.load_model("epic_num_reader.model")
# Out:
# INFO:tensorflow:Assets written to: epic_num_reader.model/assets

# %%
#test your model by randomly importing input values and testing with the predicted value
6
import matplotlib.pyplot as plt

plt.imshow(x_test[897])
plt.show()

#predict
prediction=new_model.predict([x_test])
print("The number is "+ str(np.argmax(prediction[897])))
# Out:
# The number is 5
